# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import seaborn as sb
# %matplotlib inline

# %% [markdown]
# # HWE P Values: SNP50_A

# %%
snp50a = pd.read_table('/CIFS/MUG01_N/taylorjerr/JLH/160906_imputation_test/hwe_stats/snp50_a.hwe',delim_whitespace=True)
snp50a.P.plot.hist(ylim = [0,1500], bins=100, logx=True)

# %% [markdown]
# # HWE P Values: SNP50_B

# %%
snp50b = pd.read_table('/CIFS/MUG01_N/taylorjerr/JLH/160906_imputation_test/hwe_stats/snp50_b.hwe',delim_whitespace=True)
snp50b.P.plot.hist(ylim = [0,1500], bins=100, logx=True)

# %% [markdown]
# # HWE P Values: SNP50_C

# %%
snp50c= pd.read_table('/CIFS/MUG01_N/taylorjerr/JLH/160906_imputation_test/hwe_stats/snp50_c.hwe',delim_whitespace=True)
snp50c.P.plot.hist(ylim = [0,1500],bins=100, logx=True)

# %% [markdown]
# # HWE P Values: GGPF250

# %%
ggpf250 = pd.read_table('/CIFS/MUG01_N/taylorjerr/JLH/160906_imputation_test/hwe_stats/ggpf250.hwe',delim_whitespace=True)
ggpf250.P.plot.hist(ylim = [0,4000],bins=100, logx=True)

# %% [markdown]
# # HWE P Values: HD

# %%
hd = pd.read_table('/CIFS/MUG01_N/taylorjerr/JLH/160906_imputation_test/hwe_stats/hd.hwe',delim_whitespace=True)
hd.P.plot.hist(ylim = [0,20000],bins=100, logx=True)
