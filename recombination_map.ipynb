# %%
import pandas as pd
import numpy as np
import lxml

# %%
map = pd.read_csv('../../RecombinationMap_170802.csv', usecols=['chr', 'chr_pos', 'map_f', 'map_m'])

# %%
newmap = (map.assign(recomb = (map.map_f+map.map_m)/2)
          .assign(step = .chr_pos)
        [ ['chr', 'chr_pos', 'recomb']])

# %%
# !head cattle_rmap.txt
# Out:
# Name Chr Location map_f map_m
# BovineHD0100000035 1 120183 0 1.4782062493535e-05
# Hapmap43437-BTA-101873 1 135098 3.4117582112158e-05 1.22998722308923e-05
# BovineHD0100000048 1 158820 3.4117582112158e-05 2.90941750234027e-05
# BovineHD0100000057 1 183040 3.4117582112158e-05 2.90941750234027e-05
# BovineHD0100000064 1 208728 3.4117582112158e-05 2.90941750234027e-05
# ARS-BFGL-NGS-16466 1 267940 6.74631245713206e-05 6.8156985639748e-05
# BovineHD0100000079 1 278952 6.74631245713206e-05 6.8156985639748e-05
# BovineHD0100000082 1 290690 6.74631245713206e-05 6.8156985639748e-05
# BovineHD0100000086 1 309487 6.74631245713206e-05 6.8156985639748e-05

# %%
# !tail cattle_rmap.txt
# Out:
# ARS-BFGL-NGS-106356 29 51438462 7.84687962204037e-20 3.83507652168495e-05
# BovineHD2900014964 29 51468335 7.84687962204037e-20 3.83507652168495e-05
# ARS-BFGL-NGS-64321 29 51481890 0.000139772029943357 0.000660920539812099
# BovineHD2900015101 29 51492483 0.000139772029943357 6.31726678432768e-05
# ARS-BFGL-NGS-29340 29 51502868 0.00144322135983351 0.000918538565349718
# ARS-BFGL-NGS-25386 29 51502869 1.33694270972967e-81 0
# ARS-BFGL-NGS-32260 29 51502870 1.0059512414774e-92 0
# Hapmap52103-rs29026528 29 51502871 1.99908990999019e-05 1.61349487525772e-05
# Hapmap53560-ss46526467 29 51502872 1.97280770903716e-05 0
# ARS-BFGL-NGS-108538 29 51502873 0 0

# %%
map = pd.read_table('./cattle_rmap.txt', delim_whitespace=True, usecols=['Chr', 'Location', 'map_f', 'map_m'])

# %%
map['rr']=(map.map_f+map.map_m)/2

# %%
# Out:
#     Chr  Location         map_f         map_m            rr
# 0     1    120183  0.000000e+00  1.478206e-05  7.391031e-06
# 1     1    135098  3.411758e-05  1.229987e-05  2.320873e-05
# 2     1    158820  3.411758e-05  2.909418e-05  3.160588e-05
# 3     1    183040  3.411758e-05  2.909418e-05  3.160588e-05
# 4     1    208728  3.411758e-05  2.909418e-05  3.160588e-05
# 5     1    267940  6.746312e-05  6.815699e-05  6.781006e-05
# 6     1    278952  6.746312e-05  6.815699e-05  6.781006e-05
# 7     1    290690  6.746312e-05  6.815699e-05  6.781006e-05
# 8     1    309487  6.746312e-05  6.815699e-05  6.781006e-05
# 9     1    393248  2.181423e-04  1.824260e-04  2.002841e-04
# 10    1    413044  2.181423e-04  1.824260e-04  2.002841e-04
# 11    1    458718  2.181423e-04  1.824260e-04  2.002841e-04
# 12    1    471078  3.065162e-26  5.892888e-10  2.946444e-10
# 13    1    473223  3.065162e-26  5.892888e-10  2.946444e-10
# 14    1    516404  6.775880e-05  2.348326e-31  3.387940e-05
# ...
